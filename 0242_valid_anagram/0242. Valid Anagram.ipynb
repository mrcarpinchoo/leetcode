# %% [markdown]
# **242. Valid Anagram**: Given two strings `s` and `t`, return `true` if `t` is an anagram of `s`, and `false` otherwise.
#
# **Example 1**:
#
# Input: `s = "anagram"`, `t = "nagaram"`
#
# Output: `true`
#
# **Example 2**:
#
# Input: `s = "rat"`, `t = "car"`
#
# Output: `false`
#
# **Constraints**:
# - `1 <= s.length`, `t.length <= 5 * 10^4`
# - `s` and `t` consist of lowercase English letters.
#
#
# Follow up: What if the inputs contain Unicode characters? How would you adapt your solution to such a case?

# %% [markdown]
# ### Solution 1: Hash Table Approach
# This solution determines whether two strings are anagrams by using one hash table to balance character frequencies.
#
# 1. If the lengths of `s` and `t` are different, return `False`.
# 2. Create an empty hash table.
# 3. Iterate once through both strings using the same index:
#     - Increase the count for `s[i]` by `1`.
#     - Decrease the count for `t[i]` by `1`.
# 4. After the loop, iterate through the hash table:
#     - If any frequency is not `0`, return `False`.
# 5. If all frequencies are `0`, return `True`.
#
# The key idea is to increment counts for characters in `s` and decrement counts for characters in `t`.
#
# If the strings are anagrams, every character’s net frequency will end at zero.
#
# - Time complexity: $O(n)$
# - Space complexity: $O(n)$

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        hash_table = {}

        if len(s) != len(t): return False

        for i in range(len(s)):
            if s[i] not in hash_table: hash_table[s[i]] = 1
            else: hash_table[s[i]] += 1
            # end if-else

            if t[i] not in hash_table: hash_table[t[i]] = -1
            else: hash_table[t[i]] -= 1
            # end if-else
        # end for-in

        for key, freq in hash_table.items():
            if freq != 0: return False
            # end if
        # end for-in

        return True
    # end def
# end class

# %%
solution = Solution()

print(solution.isAnagram("anagram", "nagaram"))  # True
print(solution.isAnagram("rat", "car"))  # False
# Out:
# True
# False
